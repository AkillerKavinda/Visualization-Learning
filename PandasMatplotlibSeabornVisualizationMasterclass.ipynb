# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Age": [25, 30, 35, 40, 28],
    "Salary": [50000, 60000, 65000, 70000, 58000],
    "Department": ["HR", "IT", "IT", "Finance", "HR"],
    "Gender": ["F", "M", "M", "M", "F"]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Salary Department Gender
# 0    Alice   25   50000         HR      F
# 1      Bob   30   60000         IT      M
# 2  Charlie   35   65000         IT      M
# 3    David   40   70000    Finance      M
# 4      Eva   28   58000         HR      F

# %%
df.plot(kind="line", x = "Name", y = "Salary")
# Out:
# <Axes: xlabel='Name'>

# %%
df.plot(kind="bar", x = "Department", y="Salary")
# Out:
# <Axes: xlabel='Department'>

# %%
df["Age"].plot(kind="hist", bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="scatter", x= "Age", y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
df.head()
# Out:
#       Name  Age  Salary Department Gender
# 0    Alice   25   50000         HR      F
# 1      Bob   30   60000         IT      M
# 2  Charlie   35   65000         IT      M
# 3    David   40   70000    Finance      M
# 4      Eva   28   58000         HR      F

# %%
df["Department"].value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(x="Department", y="Salary", data=df)
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
sns.countplot(x="Gender", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.violinplot(x="Salary", data=df)
# Out:
# <Axes: xlabel='Salary'>

# %%
# Practicing Again

# %%
df.head()
# Out:
#       Name  Age  Salary Department Gender
# 0    Alice   25   50000         HR      F
# 1      Bob   30   60000         IT      M
# 2  Charlie   35   65000         IT      M
# 3    David   40   70000    Finance      M
# 4      Eva   28   58000         HR      F

# %%
df.plot(kind="line", x="Name", y="Salary")
# Out:
# <Axes: xlabel='Name'>

# %%
df.plot(kind="bar", x = "Department", y="Salary")
# Out:
# <Axes: xlabel='Department'>

# %%
df["Age"].plot(kind="hist", bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="scatter",x ="Age", y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
df["Department"].value_counts().plot(kind="pie", autopct="%1.f%%")
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(x="Department", y="Salary", data=df)
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
sns.violinplot(x="Department", y="Salary",data=df)
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
sns.scatterplot(data=df, x="Age",y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.countplot(data=df, x="Department")
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
df.head()
# Out:
#       Name  Age  Salary Department Gender
# 0    Alice   25   50000         HR      F
# 1      Bob   30   60000         IT      M
# 2  Charlie   35   65000         IT      M
# 3    David   40   70000    Finance      M
# 4      Eva   28   58000         HR      F

# %%
# Which department has the most males

df.groupby("Department")["Gender"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Department,Gender'>

# %%
df.head(20)
# Out:
#       Name  Age  Salary Department Gender
# 0    Alice   25   50000         HR      F
# 1      Bob   30   60000         IT      M
# 2  Charlie   35   65000         IT      M
# 3    David   40   70000    Finance      M
# 4      Eva   28   58000         HR      F

# %%
df.groupby("Department")["Salary"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Department'>

# %%
df["Age"].plot(kind="hist",bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="scatter", x="Age", y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.boxplot(x="Department", y="Salary", data=df)
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
sns.violinplot(x="Department", y="Salary", data=df)
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
df.head()
# Out:
#       Name  Age  Salary Department Gender
# 0    Alice   25   50000         HR      F
# 1      Bob   30   60000         IT      M
# 2  Charlie   35   65000         IT      M
# 3    David   40   70000    Finance      M
# 4      Eva   28   58000         HR      F

# %%
sns.countplot(x="Department", data=df)
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
# Summarizing again

# %%
plt.plot(df["Name"], df["Salary"])

# %%
plt.bar(df["Name"], df["Salary"])
# Out:
# <BarContainer object of 5 artists>

# %%
df.plot(kind="bar", x="Name", y="Salary")
# Out:
# <Axes: xlabel='Name'>

# %%
plt.scatter(df["Age"],df["Salary"])

# %%
plt.hist(df["Age"], bins=5)
# Out:
# (array([1., 2., 0., 1., 1.]),
#  array([25., 28., 31., 34., 37., 40.]),
#  <BarContainer object of 5 artists>)

# %%
sns.barplot(data=df, x="Department", y="Salary")
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
sns.countplot(data=df, x="Department")
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
sns.boxplot(data=df, x="Department", y="Salary")
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
sns.violinplot(data=df, x="Department", y="Salary")
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
sns.scatterplot(data=df, x="Age", y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.lineplot(data=df, x="Name", y="Salary")
# Out:
# <Axes: xlabel='Name', ylabel='Salary'>

# %%
sns.scatterplot(x="Age", y="Salary",hue="Gender", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %% [markdown]
# # Final revision

# %%
## Line, Bar, Histogram, Scatter, Pie, Box, Violin, Count

# %%
df.head()
# Out:
#       Name  Age  Salary Department Gender
# 0    Alice   25   50000         HR      F
# 1      Bob   30   60000         IT      M
# 2  Charlie   35   65000         IT      M
# 3    David   40   70000    Finance      M
# 4      Eva   28   58000         HR      F

# %% [markdown]
# # Line Plots

# %%
df.plot(kind="line", x="Name", y="Salary")
# Out:
# <Axes: xlabel='Name'>

# %%
plt.plot(df["Name"], df["Salary"])

# %%
sns.lineplot(data=df, x="Name", y="Salary")
# Out:
# <Axes: xlabel='Name', ylabel='Salary'>

# %% [markdown]
# # Bar Plots

# %%
df.head()
# Out:
#       Name  Age  Salary Department Gender
# 0    Alice   25   50000         HR      F
# 1      Bob   30   60000         IT      M
# 2  Charlie   35   65000         IT      M
# 3    David   40   70000    Finance      M
# 4      Eva   28   58000         HR      F

# %%
df.plot(kind="bar", x="Department",y="Salary")
# Out:
# <Axes: xlabel='Department'>

# %%
plt.bar(df["Department"], df["Salary"])
# Out:
# <BarContainer object of 5 artists>

# %%
sns.barplot(data=df, x="Department", y="Salary")
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %% [markdown]
# # Histograms

# %%
df.head()
# Out:
#       Name  Age  Salary Department Gender
# 0    Alice   25   50000         HR      F
# 1      Bob   30   60000         IT      M
# 2  Charlie   35   65000         IT      M
# 3    David   40   70000    Finance      M
# 4      Eva   28   58000         HR      F

# %%
df["Age"].plot(kind="hist", bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.hist(df["Age"], bins=5)
# Out:
# (array([1., 2., 0., 1., 1.]),
#  array([25., 28., 31., 34., 37., 40.]),
#  <BarContainer object of 5 artists>)

# %%
sns.histplot(data=df, x="Age",bins =5)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# # Scatter plots

# %%
df.plot(kind="scatter", x="Age", y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
plt.scatter(df["Age"], df["Salary"])

# %%
sns.scatterplot(data=df, x="Age", y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %% [markdown]
# # Pie Charts

# %%
df["Department"].value_counts().plot(kind="pie", autopct="%.1f%%") # % - start, .1f - one decimal floating number, %% - add percentage in the end
# .2f - 2 decimal floating number
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Box Plots

# %%
sns.boxplot(data=df, x="Department", y="Salary")
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(data=df, x="Department", y="Salary")
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %% [markdown]
# # Count plots

# %%
sns.countplot(data=df, x="Department")
# Out:
# <Axes: xlabel='Department', ylabel='count'>
